# %%
import sys
sys.path.append("../")

import pandas as pd
import plotly.graph_objects as go
from dateutil import parser
import datetime as dt

from api.oanda_api import OandaApi
from infrastructure.instrument_collection import instrumentCollection as ic
from db.db import DataDB

pd.set_option('display.max_rows', None)

# %%
database = DataDB()

# %%
ic.LoadInstrumentsDB()

# %%
pairs = []
for pair, val in ic.instruments_dict.items():
    if val.ins_type == "CURRENCY" and "GBP" in pair:
        pairs.append(pair)

# %%
pairs
# Out:
# ['GBP_AUD',
#  'GBP_CHF',
#  'GBP_CAD',
#  'GBP_HKD',
#  'GBP_ZAR',
#  'GBP_USD',
#  'GBP_SGD',
#  'GBP_PLN',
#  'GBP_NZD',
#  'EUR_GBP',
#  'GBP_JPY']

# %%
data = []
api = OandaApi()
for p in pairs:
    d_temp = api.get_candles_df(pair_name=p, granularity="D",count=400)
    d_temp['gain'] = ((d_temp.mid_c - d_temp.mid_o) / d_temp.mid_c) * 100
    d_temp['pair'] = p
    if '_GBP' in p:
        d_temp['gain'] = d_temp['gain'] * -1
    data.append(d_temp)
candles_df = pd.concat(data)
candles_df.reset_index(drop=True, inplace=True)
candles_df.time = candles_df.time.dt.date
#above line of code changes the date to easily readable format

# %%
candles_df.head()
# Out:
#          time  volume    mid_o    mid_h    mid_l    mid_c    bid_o    bid_h  \
# 0  2023-01-03  295221  1.77808  1.78162  1.75051  1.76284  1.77599  1.78152
# 1  2023-01-04  238900  1.76506  1.77018  1.75431  1.76416  1.76301  1.77005
# 2  2023-01-05  280769  1.76293  1.76464  1.75580  1.75898  1.76089  1.76449
# 3  2023-01-08  218092  1.75712  1.76320  1.75034  1.76264  1.75491  1.76310
# 4  2023-01-09  203334  1.76188  1.76838  1.75838  1.76255  1.75990  1.76830
#
#      bid_l    bid_c    ask_o    ask_h    ask_l    ask_c      gain     pair
# 0  1.75039  1.76271  1.78016  1.78206  1.75061  1.76296 -0.864514  GBP_AUD
# 1  1.75420  1.76403  1.76712  1.77032  1.75442  1.76428 -0.051016  GBP_AUD
# 2  1.75570  1.75869  1.76497  1.76644  1.75587  1.75926 -0.224562  GBP_AUD
# 3  1.75017  1.76251  1.75933  1.76331  1.75049  1.76278  0.313167  GBP_AUD
# 4  1.75722  1.76237  1.76387  1.76847  1.75851  1.76273  0.038013  GBP_AUD

# %%
calendar_data = database.query_all(DataDB.CALENDAR_COLL)

# %%
calendar_data_df = pd.DataFrame.from_dict(calendar_data)

# %%
calendar_data_df.date = calendar_data_df.date.dt.date

# %%
calendar_data_df_uk = calendar_data_df[calendar_data_df.country == "united kingdom"].copy()

# %%
calendar_data_df_uk.head(100)
# Out:
#            date         country                category  \
# 9    2024-01-12  united kingdom         monthly gdp mom
# 13   2024-01-16  united kingdom       unemployment rate
# 18   2024-01-17  united kingdom          inflation rate
# 22   2024-01-19  united kingdom        retail sales mom
# 59   2024-02-01  united kingdom           interest rate
# 73   2024-02-13  united kingdom       unemployment rate
# 79   2024-02-14  united kingdom          inflation rate
# 81   2024-02-15  united kingdom         gdp growth rate
# 73            unemployment rate           UKUEILOR   3.8%     3.9%     4.0%
# 79           inflation rate yoy           UKRPCJYR     4%       4%     4.1%
# 81     gdp growth rate qoq prel           UKGRYBZQ  -0.3%    -0.1%     0.0%
# 82     gdp growth rate yoy prel           UKGRYBZY  -0.2%     0.2%     0.5%
# 83                      gdp mom             GBRMGM  -0.1%     0.2%     0.0%
# 85             retail sales mom  GBRRetailSalesMoM   3.4%    -3.3%     1.2%
# 134           unemployment rate           UKUEILOR   3.9%     3.8%     3.9%
# 139                     gdp mom             GBRMGM   0.2%    -0.1%     0.1%
# 150          inflation rate yoy           UKRPCJYR   3.4%       4%     3.5%
# 156  boe interest rate decision           UKBRBASE  5.25%    5.25%    5.25%
# 158            retail sales mom  GBRRetailSalesMoM     0%     3.6%    -0.5%
# 202                     gdp mom             GBRMGM   0.1%     0.3%       0%
# 209           unemployment rate           UKUEILOR   4.2%     4.0%     4.0%
# 215          inflation rate yoy           UKRPCJYR   3.2%     3.4%     3.1%
# 217            retail sales mom  GBRRetailSalesMoM     0%     0.1%     0.2%
# 256  boe interest rate decision           UKBRBASE  5.25%    5.25%    5.25%
# 257    gdp growth rate qoq prel           UKGRYBZQ   0.6%    -0.3%     0.3%
# 258    gdp growth rate yoy prel           UKGRYBZY   0.2%    -0.2%     0.1%
# 259                     gdp mom             GBRMGM   0.4%     0.2%     0.2%
# 264           unemployment rate           UKUEILOR   4.3%     4.2%     4.2%
# 282          inflation rate yoy           UKRPCJYR   2.3%     3.2%     2.3%
# 286            retail sales mom  GBRRetailSalesMoM  -2.3%    -0.2%    -0.2%
# 322           unemployment rate           UKUEILOR   4.4%     4.3%     4.3%
# 324                     gdp mom             GBRMGM     0%     0.4%     0.1%
# 341          inflation rate yoy           UKRPCJYR     2%     2.3%     1.9%
# 342  boe interest rate decision           UKBRBASE  5.25%    5.25%    5.25%
# 345            retail sales mom  GBRRetailSalesMoM   2.9%    -1.8%     1.6%
# 372         uk general election       GBP CALENDAR
# 383                     gdp mom             GBRMGM   0.4%       0%     0.1%
# 398          inflation rate yoy           UKRPCJYR     2%       2%     2.0%
# 401           unemployment rate           UKUEILOR   4.4%     4.4%     4.4%
# 406            retail sales mom  GBRRetailSalesMoM            2.9%    -0.2%
# 438  boe interest rate decision           UKBRBASE                     5.0%
# 452           unemployment rate           UKUEILOR            4.4%     4.5%
# 455          inflation rate yoy           UKRPCJYR
# 463    gdp growth rate qoq prel           UKGRYBZQ                     0.1%
# 464    gdp growth rate yoy prel           UKGRYBZY                     0.9%
# 465                     gdp mom             GBRMGM            0.4%     0.2%
# 467            retail sales mom  GBRRetailSalesMoM
# 508           unemployment rate           UKUEILOR                     4.5%
# 509                     gdp mom             GBRMGM
# 527          inflation rate yoy           UKRPCJYR
# 532  boe interest rate decision           UKBRBASE
# 535            retail sales mom  GBRRetailSalesMoM
# 571                     gdp mom             GBRMGM
# 577           unemployment rate           UKUEILOR                     4.6%
# 580          inflation rate yoy           UKRPCJYR                     2.2%
# 590            retail sales mom  GBRRetailSalesMoM                     0.4%
# 630  boe interest rate decision           UKBRBASE
# 637           unemployment rate           UKUEILOR                     4.6%
# 645    gdp growth rate qoq prel           UKGRYBZQ                     0.2%
# 646    gdp growth rate yoy prel           UKGRYBZY                     1.2%
# 647                     gdp mom             GBRMGM
# 653            retail sales mom  GBRRetailSalesMoM
# 658          inflation rate yoy           UKRPCJYR
# 701                     gdp mom             GBRMGM
# 711           unemployment rate           UKUEILOR                     4.7%
# 717          inflation rate yoy           UKRPCJYR
# 724  boe interest rate decision           UKBRBASE

# %%
calendar_data_df_uk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 64 entries, 9 to 724
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      64 non-null     object
#  1   country   64 non-null     object
#  2   category  64 non-null     object
#  3   event     64 non-null     object
#  4   symbol    64 non-null     object
#  5   actual    64 non-null     float64
#  6   previous  64 non-null     float64
#  7   forecast  64 non-null     float64
# dtypes: float64(3), object(5)
# memory usage: 4.5+ KB

# %%
for col in ['actual', 'previous', 'forecast']:
    for sy in ['£', '%', 'B', 'K']:
        calendar_data_df_uk[col] = calendar_data_df_uk[col].str.replace(sy, "")
    calendar_data_df_uk[col].replace('', 0, inplace=True)
    calendar_data_df_uk[col] = calendar_data_df_uk[col].astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 3
#       1 for col in ['actual', 'previous', 'forecast']:
#       2     for sy in ['£', '%', 'B', 'K']:
# ----> 3         calendar_data_df_uk[col] = calendar_data_df_uk[col].str.replace(sy, "")
#       4     calendar_data_df_uk[col].replace('', 0, inplace=True)
#       5     calendar_data_df_uk[col] = calendar_data_df_uk[col].astype(float)
#
# File c:\users\aaron\desktop\forexalgo\code\forexenv\lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# File c:\users\aaron\desktop\forexalgo\code\forexenv\lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File c:\users\aaron\desktop\forexalgo\code\forexenv\lib\site-packages\pandas\core\strings\accessor.py:181, in StringMethods.__init__(self, data)
#     178 def __init__(self, data) -> None:
#     179     from pandas.core.arrays.string_ import StringDtype
# --> 181     self._inferred_dtype = self._validate(data)
#     182     self._is_categorical = is_categorical_dtype(data.dtype)
#     183     self._is_string = isinstance(data.dtype, StringDtype)
#
# File c:\users\aaron\desktop\forexalgo\code\forexenv\lib\site-packages\pandas\core\strings\accessor.py:235, in StringMethods._validate(data)
#     232 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     234 if inferred_dtype not in allowed_types:
# --> 235     raise AttributeError("Can only use .str accessor with string values!")
#     236 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
date_match = {}
for orig in calendar_data_df_uk.date.unique():
    d = orig
    tries = 0
    while d not in candles_df.time.values:
        d = d + dt.timedelta(days=1)
        tries += 1
        if tries > 15:
            print("Failed")
            break
    date_match[orig] = d
# Out:
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed

# %%
calendar_data_df_uk['orig_date'] = calendar_data_df_uk.date
calendar_data_df_uk.date = [date_match[x] for x in calendar_data_df_uk.date]

# %%
calendar_data_df_uk['delta_prev'] = calendar_data_df_uk.actual - calendar_data_df_uk.previous
calendar_data_df_uk['delta_fc'] = calendar_data_df_uk.actual - calendar_data_df_uk.forecast

# %%
calendar_data_df_uk.head(2)

# %%
candles_an.head(2)

# %%
candles_an = candles_df[['time', 'pair', 'gain']].copy()

# %%
merged = pd.merge(left=candles_an, right=calendar_data_df_uk, left_on='time', right_on='date')

# %%
merged[merged.category=='inflation rate'].head(2)

# %%
merged.category.unique()

# %%
c = 'consumer confidence'
df_an = merged[merged.category==c]
print(df_an[df_an.delta_fc >= 0].gain.sum())
print(df_an[df_an.delta_fc < 0].gain.sum())

# %%
import plotly.express as px

# %%
cat = 'inflation rate'
df_cat = merged[merged.category==cat]
for p in pairs:
    df_plot = df_cat[df_cat.pair == p]
    print(p)
    fig = px.scatter(df_plot, x="gain", y="delta_prev", trendline="ols")
    fig.show()
